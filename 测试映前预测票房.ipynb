# %% [markdown]
# ### 导入相关文件

# %%
source("before_predict_box.R", encoding = "utf-8")
# Out:
# Warning message:
# "`axis.ticks.margin` is deprecated. Please set `margin` property  of `axis.text` instead"

# %% [markdown]
# ### 建模

# %%
# 映前预测票房
fit_result <- before_predict_allbox_model("final_data_5_gbk.csv", "predict_data.csv", "firbox")
# Out:
#  chr [1:730] "喜剧" "爱情" "喜剧" "爱情" "喜剧" "恐怖" "喜剧" "纪录片" ...
#  Factor w/ 16 levels "爱情","动画",..: 13 1 13 1 13 10 13 6 13 13 ...
#  Factor w/ 22 levels "爱情","传记",..: 17 1 17 1 17 12 17 7 17 17 ...
# plot without title
# plot without title
# [1] -1.515152
# Warning message in plot.window(xlim, ylim, "", ...):
# ""title"不是图形参数"Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# ""title"不是图形参数"Warning message in axis(1, ...):
# ""title"不是图形参数"Warning message in axis(2, ...):
# ""title"不是图形参数"
# plot without title
# [1] 0.06060606
# Warning message in replayPlot(obj):
# ""title"不是图形参数"Warning message in replayPlot(obj):
# ""title"不是图形参数"Warning message in replayPlot(obj):
# ""title"不是图形参数"Warning message in replayPlot(obj):
# ""title"不是图形参数"
# Plot with title "Normal Q-Q Plot"
# Warning message in plot.window(xlim, ylim, "", ...):
# ""title"不是图形参数"Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# ...

# %% [markdown]
# ### 预测新电影

# %%
report <- fit_result[[2]]
report
# Out:
#     name     real_box
# 729 云南虫谷 3978.456
